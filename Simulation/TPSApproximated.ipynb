# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dim = 2
N = 50
M = int(0.58 * N ** (1/2))
L = 1
interval = (0,L)

# %%
s = np.random.default_rng().uniform(*interval,dim*N).reshape(N, dim)
if dim == 2:
    plt.scatter(s[:,0], s[:,1])

stripes = np.linspace(0,1, M+1)

for x in stripes:
    plt.plot([x,x], [0,L] )

# %%
points = {i:[[],True] for i in range(M)}

top = True
fromTop = [L,0]

for i in range(M):
    if top:
        lines[i].append([[stripes[i],stripes[i+1]], fromTop])
    else:
        lines[i].append([[stripes[i],stripes[i+1]], fromTop[::-1]])
    top = not top


p = s[0]
location = np.argmax(stripes >= p[0] )-1
if 

lines = []
for i in range(len)

for line in lines[i]:
    plt.plot(*line)
# Out:
# array([0.83612016, 0.96257604])

# %%
np.arange(0,10)[::-1]
# Out:
# array([9, 8, 7, 6, 5, 4, 3, 2, 1, 0])
